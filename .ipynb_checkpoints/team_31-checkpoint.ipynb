# %%
# Import the Pandas package
import pandas as pd

# Import the NumPy package
import numpy as np

# %%
df = pd.read_csv("eo_il.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of              EIN                                               NAME  \
# 0        3390819                   REP RESOURCES EMPOWERING PARENTS
# 1       10438881             SHADY NOOK IMPROVEMENT ASSOCIATION INC
# 2       10482439                          MODERN WOODMEN OF AMERICA
# 3       10492125   ALLIANCE OF INDEPENDENT ACADEMIC MEDICAL CENTERS
# 4       10516987           ASSOCIATION OF PEDIATRIC ONCOLOGY NURSES
# 5       10532058                                         SIETAR USA
# 6       10550386                                         SHOREFRONT
# 7       10551710      DOWNERS GROVE JR WOMANS CLUB CHARITY FUND INC
# 8       10552691                    FULCRUM POINT NEW MUSIC PROJECT
# 9       10556625                                    MAAK FOUNDATION
# 10      10557303          GREATER ROCHELLE AREA CHRISTIAN EDUCATORS
# 11      10558182                             JCPE INVESTMENTS N F P
# ...
